# %% [markdown]
# ## 1. Import required Libraries

# %%
# !pip install xgboost scikit-learn pandas cleanlab
# !pip install importnb

# %%
import sys
import os
sys.path.append(os.path.abspath("C:/Users/Admin/OneDrive - University of Huddersfield/Data-driven-AI/Assignment 2"))

# %%
import os
import tensorflow as tf
import cv2
import cleanlab
import importnb
from importnb import Notebook
with Notebook():
    import labelling_error as le

# %% [markdown]
# ## 2. Loading the Data

# %%
folder_path_of_stage_1 = 'C:/Users/Admin/OneDrive - University of Huddersfield/Data-driven-AI/Assignment 2/CHS2406_Coursework2_Data_Repository/Stage1'

dataset_path = 'C:/Users/Admin/OneDrive - University of Huddersfield/Data-driven-AI/Assignment 2/dataset'
os.makedirs(dataset_path, exist_ok=True)

for filename in os.listdir(folder_path_of_stage_1):
    image_path = os.path.join(folder_path_of_stage_1, filename)
    try:
        image = cv2.imread(image_path)

        if image is None:
            print(f"Cannot read file: {filename}. The image variable returns none.")
            continue

        output_path = os.path.join(dataset_path, filename)
        cv2.imwrite(output_path, image)
    except Exception as e:
        print(f"Cannot read file:: {filename}. Reason: {e}")
# Out:
# Cannot read file: stage 1 _ 7 u2362759.heic. The image variable returns none.
# Cannot read file: stage 1_ 10 u2362759.heic. The image variable returns none.
# Cannot read file: stage 1_1 u2362759.heic. The image variable returns none.
# Cannot read file: stage 1_2 u2362759.heic. The image variable returns none.
# Cannot read file: stage 1_3 u2362759.heic. The image variable returns none.
# Cannot read file: stage 1_4u2362759.heic. The image variable returns none.
# Cannot read file: stage 1_5u2362759.heic. The image variable returns none.
# Cannot read file: stage 1_6u2362759.heic. The image variable returns none.
# Cannot read file: stage 1_8 u2362759.heic. The image variable returns none.
# Cannot read file: stage 1_9 u2362759.heic. The image variable returns none.
# Cannot read file: stage1_1 u2364895.heic. The image variable returns none.
# Cannot read file: stage1_10 u2364895.heic. The image variable returns none.
# ...

# %%
folder_path_of_stage_2 = 'C:/Users/Admin/OneDrive - University of Huddersfield/Data-driven-AI/Assignment 2/CHS2406_Coursework2_Data_Repository/Stage2'

dataset_path = 'C:/Users/Admin/OneDrive - University of Huddersfield/Data-driven-AI/Assignment 2/dataset'
os.makedirs(dataset_path, exist_ok=True)

for filename in os.listdir(folder_path_of_stage_2):
    image_path = os.path.join(folder_path_of_stage_2, filename)
    try:
        image = cv2.imread(image_path)

        if image is None:
            print(f"Cannot read file: {filename}. The image variable returns none.")
            continue

        output_path = os.path.join(dataset_path, filename)
        cv2.imwrite(output_path, image)
    except Exception as e:
        print(f"Cannot read file:: {filename}. Reason: {e}")
# Out:
# Cannot read file: stage 2_ 1 u2362759.heic. The image variable returns none.
# Cannot read file: stage 2_ 10 u2362759.heic. The image variable returns none.
# Cannot read file: stage 2_ 2 u2362759.heic. The image variable returns none.
# Cannot read file: stage 2_ 3 u2362759.heic. The image variable returns none.
# Cannot read file: stage 2_ 4 u2362759.heic. The image variable returns none.
# Cannot read file: stage 2_ 5 u2362759.heic. The image variable returns none.
# Cannot read file: stage 2_ 6 u2362759.heic. The image variable returns none.
# Cannot read file: stage 2_ 7 u2362759.heic. The image variable returns none.
# Cannot read file: stage 2_ 8 u2362759.heic. The image variable returns none.
# Cannot read file: stage 2_ 9 u2362759.heic. The image variable returns none.
# Cannot read file: stage2_1 u2364895.heic. The image variable returns none.
# Cannot read file: stage2_10 u2364895.heic. The image variable returns none.
# ...

# %%
folder_path_of_stage_3 = 'C:/Users/Admin/OneDrive - University of Huddersfield/Data-driven-AI/Assignment 2/CHS2406_Coursework2_Data_Repository/Stage3'

dataset_path = 'C:/Users/Admin/OneDrive - University of Huddersfield/Data-driven-AI/Assignment 2/dataset'
os.makedirs(dataset_path, exist_ok=True)

for filename in os.listdir(folder_path_of_stage_3):
    image_path = os.path.join(folder_path_of_stage_3, filename)
    try:
        image = cv2.imread(image_path)

        if image is None:
            print(f"Cannot read file: {filename}. The image variable returns none.")
            continue

        output_path = os.path.join(dataset_path, filename)
        cv2.imwrite(output_path, image)
    except Exception as e:
        print(f"Cannot read file:: {filename}. Reason: {e}")
# Out:
# Cannot read file: stage 3_ 1 u2362759.heic. The image variable returns none.
# Cannot read file: stage 3_ 10 u2362759.heic. The image variable returns none.
# Cannot read file: stage 3_ 2 u2362759.heic. The image variable returns none.
# Cannot read file: stage 3_ 3 u2362759.heic. The image variable returns none.
# Cannot read file: stage 3_ 4 u2362759.heic. The image variable returns none.
# Cannot read file: stage 3_ 5 u2362759.heic. The image variable returns none.
# Cannot read file: stage 3_ 6 u2362759.heic. The image variable returns none.
# Cannot read file: stage 3_ 7 u2362759.heic. The image variable returns none.
# Cannot read file: stage 3_ 8 u2362759.heic. The image variable returns none.
# Cannot read file: stage 3_ 9 u2362759.heic. The image variable returns none.
# Cannot read file: stage3_ u2364895.heic. The image variable returns none.
# Cannot read file: stage3_10 u2364895.heic. The image variable returns none.
# ...

# %%
folder_path_of_stage_4 = 'C:/Users/Admin/OneDrive - University of Huddersfield/Data-driven-AI/Assignment 2/CHS2406_Coursework2_Data_Repository/Stage4'

dataset_path = 'C:/Users/Admin/OneDrive - University of Huddersfield/Data-driven-AI/Assignment 2/dataset'
os.makedirs(dataset_path, exist_ok=True)

for filename in os.listdir(folder_path_of_stage_4):
    image_path = os.path.join(folder_path_of_stage_4, filename)
    try:
        image = cv2.imread(image_path)

        if image is None:
            print(f"Cannot read file: {filename}. The image variable returns none.")
            continue

        output_path = os.path.join(dataset_path, filename)
        cv2.imwrite(output_path, image)
    except Exception as e:
        print(f"Cannot read file:: {filename}. Reason: {e}")
# Out:
# Cannot read file: IMG_0226.heic. The image variable returns none.
# Cannot read file: IMG_0227.heic. The image variable returns none.
# Cannot read file: IMG_0228.heic. The image variable returns none.
# Cannot read file: IMG_0229.heic. The image variable returns none.
# Cannot read file: IMG_0230.heic. The image variable returns none.
# Cannot read file: IMG_0231.heic. The image variable returns none.
# Cannot read file: IMG_0232.heic. The image variable returns none.
# Cannot read file: IMG_0233.heic. The image variable returns none.
# Cannot read file: IMG_0234.heic. The image variable returns none.
# Cannot read file: IMG_0235.heic. The image variable returns none.
# Cannot read file: stage 4_  8  u2362759.heic. The image variable returns none.
# Cannot read file: stage 4_ 1 u2362759.heic. The image variable returns none.
# Cannot read file: stage 4_ 10 u2362759.heic. The image variable returns none.
# Cannot read file: stage 4_ 2 u2362759.heic. The image variable returns none.
# ...

# %%
folder_path_of_stage_5 = 'C:/Users/Admin/OneDrive - University of Huddersfield/Data-driven-AI/Assignment 2/CHS2406_Coursework2_Data_Repository/Stage5'

dataset_path = 'C:/Users/Admin/OneDrive - University of Huddersfield/Data-driven-AI/Assignment 2/dataset'
os.makedirs(dataset_path, exist_ok=True)

for filename in os.listdir(folder_path_of_stage_5):
    image_path = os.path.join(folder_path_of_stage_5, filename)
    try:
        image = cv2.imread(image_path)

        if image is None:
            print(f"Cannot read file: {filename}. The image variable returns none.")
            continue

        output_path = os.path.join(dataset_path, filename)
        cv2.imwrite(output_path, image)
    except Exception as e:
        print(f"Cannot read file:: {filename}. Reason: {e}")
# Out:
# Cannot read file: stage 5_ 1 u2362759.heic. The image variable returns none.
# Cannot read file: stage 5_ 10 u2362759.heic. The image variable returns none.
# Cannot read file: stage 5_ 2 u2362759.heic. The image variable returns none.
# Cannot read file: stage 5_ 3 u2362759.heic. The image variable returns none.
# Cannot read file: stage 5_ 4 u2362759.heic. The image variable returns none.
# Cannot read file: stage 5_ 5 u2362759.heic. The image variable returns none.
# Cannot read file: stage 5_ 6 u2362759.heic. The image variable returns none.
# Cannot read file: stage 5_ 7 u2362759.heic. The image variable returns none.
# Cannot read file: stage 5_ 8 u2362759.heic. The image variable returns none.
# Cannot read file: stage 5_ 9 u2362759.heic. The image variable returns none.
# Cannot read file: Stage5_1 U2364895.heic. The image variable returns none.
# Cannot read file: Stage5_10 U2364895.heic. The image variable returns none.
# ...

# %%
folder_path_of_stage_6 = 'C:/Users/Admin/OneDrive - University of Huddersfield/Data-driven-AI/Assignment 2/CHS2406_Coursework2_Data_Repository/Stage6'

dataset_path = 'C:/Users/Admin/OneDrive - University of Huddersfield/Data-driven-AI/Assignment 2/dataset'
os.makedirs(dataset_path, exist_ok=True)

for filename in os.listdir(folder_path_of_stage_6):
    image_path = os.path.join(folder_path_of_stage_6, filename)
    try:
        image = cv2.imread(image_path)

        if image is None:
            print(f"Cannot read file: {filename}. The image variable returns none.")
            continue

        output_path = os.path.join(dataset_path, filename)
        cv2.imwrite(output_path, image)
    except Exception as e:
        print(f"Cannot read file:: {filename}. Reason: {e}")
# Out:
# Cannot read file: stage 6 _ 2 u2362759.heic. The image variable returns none.
# Cannot read file: stage 6 _ 3 u2362759.heic. The image variable returns none.
# Cannot read file: stage 6 _ 4 u2362759.heic. The image variable returns none.
# Cannot read file: stage 6 _ 5 u2362759.heic. The image variable returns none.
# Cannot read file: stage 6 _ 6 u2362759.heic. The image variable returns none.
# Cannot read file: stage 6 _ 7 u2362759.heic. The image variable returns none.
# Cannot read file: stage 6 _ 8 u2362759.heic. The image variable returns none.
# Cannot read file: stage 6 _ 9 u2362759.heic. The image variable returns none.
# Cannot read file: stage 6_ 1 u2362759.heic. The image variable returns none.
# Cannot read file: stage6_ u2364896.heic. The image variable returns none.
# Cannot read file: stage6__u2364896.heic. The image variable returns none.
# Cannot read file: stage_6_4 u2364896.heic. The image variable returns none.
# ...

# %%
folder_path_of_stage_7 = 'C:/Users/Admin/OneDrive - University of Huddersfield/Data-driven-AI/Assignment 2/CHS2406_Coursework2_Data_Repository/Stage7'

dataset_path = 'C:/Users/Admin/OneDrive - University of Huddersfield/Data-driven-AI/Assignment 2/dataset'
os.makedirs(dataset_path, exist_ok=True)

for filename in os.listdir(folder_path_of_stage_7):
    image_path = os.path.join(folder_path_of_stage_7, filename)
    try:
        image = cv2.imread(image_path)

        if image is None:
            print(f"Cannot read file: {filename}. The image variable returns none.")
            continue

        output_path = os.path.join(dataset_path, filename)
        cv2.imwrite(output_path, image)
    except Exception as e:
        print(f"Cannot read file:: {filename}. Reason: {e}")
# Out:
# Cannot read file: stage 7 _ 1 u2362759.heic. The image variable returns none.
# Cannot read file: stage 7 _ 10 u2362759.heic. The image variable returns none.
# Cannot read file: stage 7 _ 2 u2362759.heic. The image variable returns none.
# Cannot read file: stage 7 _ 3 u2362759.heic. The image variable returns none.
# Cannot read file: stage 7 _ 4u2362759.heic. The image variable returns none.
# Cannot read file: stage 7 _ 5 u2362759.heic. The image variable returns none.
# Cannot read file: stage 7 _ 6 u2362759.heic. The image variable returns none.
# Cannot read file: stage 7 _ 7 u2362759.heic. The image variable returns none.
# Cannot read file: stage 7 _ 8 u2362759.heic. The image variable returns none.
# Cannot read file: stage 7 _ 9 u2362759.heic. The image variable returns none.
# Cannot read file: stage7_ u2364896.heic. The image variable returns none.
# Cannot read file: stage7_2 u2364896.heic. The image variable returns none.
# ...

# %%
folder_path_of_stage_8 = 'C:/Users/Admin/OneDrive - University of Huddersfield/Data-driven-AI/Assignment 2/CHS2406_Coursework2_Data_Repository/Stage8'

dataset_path = 'C:/Users/Admin/OneDrive - University of Huddersfield/Data-driven-AI/Assignment 2/dataset'
os.makedirs(dataset_path, exist_ok=True)

for filename in os.listdir(folder_path_of_stage_8):
    image_path = os.path.join(folder_path_of_stage_8, filename)
    try:
        image = cv2.imread(image_path)

        if image is None:
            print(f"Cannot read file: {filename}. The image variable returns none.")
            continue

        output_path = os.path.join(dataset_path, filename)
        cv2.imwrite(output_path, image)
    except Exception as e:
        print(f"Cannot read file:: {filename}. Reason: {e}")
# Out:
# Cannot read file: stage 8 _ 1 u2362759.heic. The image variable returns none.
# Cannot read file: stage 8 _ 10 u2362759.heic. The image variable returns none.
# Cannot read file: stage 8 _ 2 u2362759.heic. The image variable returns none.
# Cannot read file: stage 8 _ 3 u2362759.heic. The image variable returns none.
# Cannot read file: stage 8 _ 4 u2362759.heic. The image variable returns none.
# Cannot read file: stage 8 _ 5 u2362759.heic. The image variable returns none.
# Cannot read file: stage 8 _ 6 u2362759.heic. The image variable returns none.
# Cannot read file: stage 8 _ 7 u2362759.heic. The image variable returns none.
# Cannot read file: stage 8 _ 8 u2362759.heic. The image variable returns none.
# Cannot read file: stage 8 _ 9 u2362759.heic. The image variable returns none.
# Cannot read file: stage_8 u2364896.heic. The image variable returns none.
# Cannot read file: stage_8_10 u2364895.heic. The image variable returns none.
# ...

# %% [markdown]
# ## 3. Data Labelling Errors

# %%
# <<insert yout code here>>

# %% [markdown]
# ## Label errors:
# **Explain what kind of errors you found in the dataset.**
# 1. Incorrect data size
# 2. Wrong file type

# %% [markdown]
# **List the total number of images left in each class/stage after the label error handling**
#
# <br>
#
# <ol>
#   <li>Stage 1: <<Number of images>></li>
#   <li>Stage 2: <<Number of images>></li>
#   <li>Stage 3: <<Number of images>></li>
#   <li>Stage 4: <<Number of images>></li>
#   <li>Stage 5: <<Number of images>></li>
#   <li>Stage 6: <<Number of images>></li>
#   <li>Stage 7: <<Number of images>></li>
#   <li>Stage 8: <<Number of images>></li>
# </ol>

# %% [markdown]
# ## 4. Pre-process the Dataset

# %%
# <<insert yout code here>>

# %% [markdown]
# ## 5. Split the data
# <br>
#
# Split the data into training, validation and testing dataset using Startification, ensuring equal class distribution.
#
# Choose appropriate values of training, validation and testing datasets.
#
# Display total number of images in each dataset split.

# %%
# <<insert yout code here>>

# %% [markdown]
# ## 6. Model Implementation

# %%
# <<insert yout code here>>

# %% [markdown]
# ## 7. Evaluate the Model

# %%
# <<insert yout code here>>

# %% [markdown]
# ### Training Curves

# %%
# <<insert yout code here>>

# %% [markdown]
# ### Make Inference
# For some unseen data, make predictions using the trained model.

# %%
# <<insert yout code here>>
